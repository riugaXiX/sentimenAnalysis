# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments

# %%
kolom = ['Konten', 'stemmed', 'Value']

df = pd.read_csv('dataset/data_clean',usecols=kolom)
df['stemmed'] = df['stemmed'].str.slice(0,512)
df['Value'] = df['Value'].replace(['POSITIF'],1)

df
# Out:
#                                                Konten
# 0   pelaksana tugas plt wali kota cimahi ngatiyana...  \
# 1   seri hp gaming redmi c pantas jadi opsi redmi ...
# 2   puluhan rumah di perumahan griya zavira desa m...
# 3   hujan diprediksi akan turun di sejumlah kota b...
# 4   pelaku pembunuhan remaja berinisial af yang di...
# 5   badan pengawas pemilu bawaslu kabupaten bandun...
# 6   indonesia sudah memasuki era populasi yang men...
# 7   majelis hakim pengadilan negeri tangerang memv...
# 8   sebuah odongodong sarat penumpang tertabrak ke...
# 9   sinetron cinta setelah cinta selasa juli dijad...
# 10  menjadi seorang petani kadang dipandang sebela...
# 11  berikut ini bacaan niat puasa seninkamis diser...
# 12  laga persikabo vs persebaya surabaya sesaat la...
# 13  frets butuan mencetak gol di menit ke pada lag...
# 14  bupati sumedang h dony ahmad munir menekankan ...
# 15  persikabo ungguli persebaya surabaya di stadio...
# 16  benfica vs newcastle united bakal berlangsung ...
# 17  langkah baim wong mendaftarkan citayam fashion...
# 18  berikut link live streaming persis solo vs dew...
# 19  plat ad trending topic di media sosial twitter...
# 20  juli sisanya atau jemaah wafat pada masa setel...
# 21  ketua majelis syura pks dr salim segaf aljufri...
# 22  pada idul adha h program green kurban bahagiak...
# 23  pemerintah kota pemkot cimahi melalui badan pe...
# 24  keberadaan museum subang yang berlokasi di wis...
# 25  berikut link streaming sinetron cinta setelah ...
# 26  kota bandung merupakan kota yang memiliki kema...
# 27  pt dahana merilis inovasi terbarunya di bidang...
# 28  jelang laga benfica vs newcastle united the ma...
# 29  siaran pers diskominfo kota bandung juli begin...
#
#                                               stemmed    Value
# 0   laksana tugas plt wali kota cimahi ngatiyana h...        1
# 1   seri hp gaming redmi c opsi redmi c tawar laya...   NETRAL
# 2   puluh rumah rumah griya zavira desa mangkuraky...  NEGATIF
# 3   hujan prediksi turun kota indonesia senin juli...   NETRAL
# 4   laku bunuh remaja inisial af temu tewas enas h...  NEGATIF
# 5   badan awas milu bawaslu kabupaten bandung bara...   NETRAL
# 6   indonesia pasuk era populasi tua ageing popula...   NETRAL
# 7   majelis hakim adil negeri tangerang vonis dakw...  NEGATIF
# 8   odongodong sarat tumpang tabrak kereta api kam...  NEGATIF
# 9   sinetron cinta cinta selasa juli jadwal tayang...   NETRAL
# 10  tani kadang pandang belah mata orang enggan ta...        1
# 11  baca niat puasa seninkamis serta doa buka utam...        1
# 12  laga persikabo vs baya surabaya stadion pakans...   NETRAL
# 13  frets butuan cetak gol menit laga persib bandu...   NETRAL
# 14  bupati sumedang h dony ahmad munir tekan pimpi...        1
# 15  persikabo unggul baya surabaya stadion pakansa...   NETRAL
# 16  benfica vs newcastle united ajang uji coba pra...        1
# 17  langkah baim daftar citayam fashion week kemen...   NETRAL
# 18  link live streaming persis solo vs dewa united...   NETRAL
# 19  plat ad trending topic media sosial twitter se...  NEGATIF
# 20  juli sisa jemaah wafat puncak haji armuzna jul...  NEGATIF
# 21  ketua majelis syura pks dr salim segaf aljufri...  NEGATIF
# 22  idul adha h program green kurban bahagia terim...        1
# 23  perintah kota pemkot cimahi badan kelola uang ...        1
# 24  ada museum subang lokasi wisma karya jantung t...        1
# 25  link streaming sinetron cinta cinta selasa jul...   NETRAL
# 26  kota bandung kota milik majemuk suku budaya ag...        1
# 27  pt dahana rilis inovasi baru bidang militer lu...        1
# 28  jelang laga benfica vs newcastle united the ma...        1
# 29  siar pers diskominfo kota bandung juli olah da...   NETRAL
